# %%
import pandas as pd

# %%
submission = pd.DataFrame({'identifier': [0, 1, 2], 'target': [4, 3, 1]})

# %%
submission = pd.DataFrame([{'identifier': 0, 'target': 4},
                          {'identifier': 0, 'target': 4},
                          {'identifier': 0, 'target': 4}])
